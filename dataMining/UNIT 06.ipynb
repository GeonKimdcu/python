# %% [markdown]
# # UNIT 06 리스트 내포로 리스트 이해하기

# %% [markdown]
# ### [표현식 for 항목 in 반복가능객체]

# %%
# for문 사용
a = [1,2,3,4]
result = []
for num in a:
    result.append(num*3)
    
print(result)
# Out:
# [3, 6, 9, 12]

# %%
# 리스트 내포 사용
a = [1,2,3,4]
result = [num * 3 for num in a]
print(result)
# Out:
# [3, 6, 9, 12]

# %% [markdown]
# ### [표현식 for 항목 in 반복가능객체 if 조건문]

# %%
a = [1,2,3,4]
result = [num * 3 for num in a if num %2 == 0]
print(result)
# Out:
# [6, 12]

# %% [markdown]
# ### [표현식 for 항목1 in 반복가능객체1 if 조건문1
# ###              for 항목2 in 반복가능객체2 if 조건문 2
# ###                                  ........
# ###              for 항목n in 반복가능객체n if 조건문n]

# %%
result = [x * y for x in range(2,10)
         for y in range(1,10)]
print(result)
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16, 18, 3, 6, 9, 12, 15, 18, 21, 24, 27, 4, 8, 12, 16, 20, 24, 28, 32, 36, 5, 10, 15, 20, 25, 30, 35, 40, 45, 6, 12, 18, 24, 30, 36, 42, 48, 54, 7, 14, 21, 28, 35, 42, 49, 56, 63, 8, 16, 24, 32, 40, 48, 56, 64, 72, 9, 18, 27, 36, 45, 54, 63, 72, 81]

# %% [markdown]
# ### 리스트 내포 예제

# %%
# myList를 복사한다. myList.copy()나 myList[:]와 동일하지만 조금 더 비효율적이다.
myList = [10, 20, 30, 40, 50]
[x for x in myList]
# Out:
# [10, 20, 30, 40, 50]

# %%
myList[:]  # 전체 출력
# Out:
# [10, 20, 30, 40, 50]

# %%
# 음수가 아닌 항목만 추린다.
myList = [10, 20, -30, 40, 50]
[x for x in myList if x>= 0]
# Out:
# [10, 20, 40, 50]

# %%
# 모든 아이템을 거듭제곱한다.
myList = [1,2,-3, 4, 5]
[x**2 for x in myList]
# Out:
# [1, 4, 9, 16, 25]

# %%
# 0이 아닌 아이템의 역수를 취한다.
myList = [0, 20, 30,-40, 50]
[1/x for x in myList if x!= 0]
# Out:
# [0.05, 0.03333333333333333, -0.025, 0.02]

# %%
# infile 파일에서 비어 있지 않은 줄을 읽어 와서 문장 앞&뒤 공백을 지운다.
infile = ["       Hello, world! \t\t\n", ",", "Life if good!!            "]
[l.strip() for l in infile if l.strip()]
# Out:
# ['Hello, world!', ',', 'Life if good!!']

# %%
# 리스트 내포를 대괄호가 아닌 소괄호로 묶으면 리스트 제너레이터 객체로 인식
(x**2 for x in myList)
# Out:
# <generator object <genexpr> at 0x000001A1B459B6D0>
