# %% [markdown]
# # 02-5 딕셔너리 자료형

# %% [markdown]
# ### 1. 딕셔너리 쌍 추가, 삭제하기

# %%
# 딕셔너리 쌍 추가하기
a = {1:'a'}
a[2]='b'
a
# Out:
# {1: 'a', 2: 'b'}

# %%
a['name'] = 'pey'
a
# Out:
# {1: 'a', 2: 'b', 'name': 'pey'}

# %%
a[3] = [1,2,3]
a
# Out:
# {1: 'a', 2: 'b', 'name': 'pey', 3: [1, 2, 3]}

# %%
# 딕셔너리 요소 삭제하기
del a[1]
a
# Out:
# {2: 'b', 'name': 'pey', 3: [1, 2, 3]}

# %% [markdown]
# ## 2. 딕셔너리에서 Key 사용해 Value 얻기

# %%
grade = {'pey':10, 'julliet':99}
print(grade['pey'])
print(grade['julliet'])
# Out:
# 10
# 99

# %%
a = {1:'a', 2:'b'}
print(a[1])
print(a[2])
# Out:
# a
# b

# %%
dic = {'name' : 'pey', 'phone' : '0119993323', 'birth': '1118'}
print(dic['name'])
print(dic['phone'])
print(dic['birth'])
# Out:
# pey
# 0119993323
# 1118

# %% [markdown]
# ### 3. 딕셔너리 만들 때 주의할 사항

# %%
# Key는 고유한 값이므로 중복되는 Key값을 설정해놓으면 하나를 제외한 나머지는 모두 무시
a = {1:'a', 1:'b'}
a
# Out:
# {1: 'b'}

# %%
# Key에 리스트는 쓸 수 없다 but, 튜플은 Key로 쓸 수 있다.
# Key값은 수정 불가능 / Value는 수정 가능
a = {[1,2]: 'hi'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-481b5f08394d> in <module>
#       1 # Key에 리스트는 쓸 수 없다 but, 튜플은 Key로 쓸 수 있다.
#       2 # Key값은 수정 불가능 / Value는 수정 가능
# ----> 3 a = {[1,2]: 'hi'}
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ### 4. 딕셔너리 관련 함수

# %%
# Key 리스트 만들기(Keys)
# a.keys()는 딕셔너리 a의 Key만을 모아서 dict_keys 객체로 돌려준다.
a = {'name':'pey', 'phone' : '0119993323', 'birth' : '1118'}
a.keys()
# Out:
# dict_keys(['name', 'phone', 'birth'])

# %%
for k in a.keys():
    print(k)
# Out:
# name
# phone
# birth

# %%
# dict_keys 객체를 리스트로 변환
list(a.keys())
# Out:
# ['name', 'phone', 'birth']

# %%
# Value 리스트 만들기(values)
a.values()
# Out:
# dict_values(['pey', '0119993323', '1118'])

# %%
# Key, Value 쌍 얻기(items)
# Key와 Value의 쌍을 튜플로 묶은 값을 dict_items객체로 돌려준다.
a.items()
# Out:
# dict_items([('name', 'pey'), ('phone', '0119993323'), ('birth', '1118')])

# %%
# Key:Value 쌍 모두 지우기(clear)
a.clear()
a
# Out:
# {}

# %%
# Key로 Value 얻기(get)
a = {'name':'pey', 'phone' : '0119993323', 'birth' : '1118'}
a.get('name')
# Out:
# 'pey'

# %%
# 존재하지 않는 키(nokey)로 값을 가져오려 할 경우 
a = {'name':'pey', 'phone' : '0119993323', 'birth' : '1118'}
print(a.get('nokey'))   # a.get('nokey')는 None 
print(a['nokey']) # a['nokey']는 Key 오류 발생
# Out:
# None
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-ecdf187d1f11> in <module>
#       2 a = {'name':'pey', 'phone' : '0119993323', 'birth' : '1118'}
#       3 print(a.get('nokey'))   # a.get('nokey')는 None
# ----> 4 print(a['nokey']) # a['nokey']는 Key 오류 발생
#
# KeyError: 'nokey'

# %%
# 딕셔너리 안에 찾으려는 Key 값이 없을 경우 미리 정해준 디폴트 값을 대신 가져오게 한다
# get(x, '디폴트 값')
a.get('foo', 'bar') # 'foo'에 해당하는 값이 없다. 따라서 디폴트 값인 'bar'를 돌려준다.
# Out:
# 'bar'

# %%
# 해당 Key가 딕셔너리 안에 있는지 조사하기(in)

# %%
a = {'name':'pey', 'phone' : '0119993323', 'birth' : '1118'}
print('name'in a)
print('email'in a)
# Out:
# True
# False

# %% [markdown]
# #### p.96 나 혼자 코딩!

# %%
dic = {'name':'홍길동', 'birth' : 1128, 'age':30}

# %% [markdown]
# ### 연습문제

# %% [markdown]
# #### p.114 Q10

# %%
a = {'A':90, 'B': 80, 'C':70}
result = a.pop('B')
print(a)
print(result)
# Out:
# {'A': 90, 'C': 70}
# 80
