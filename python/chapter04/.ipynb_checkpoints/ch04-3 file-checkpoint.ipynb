# %% [markdown]
# # 04-3 파일 읽고 쓰기

# %% [markdown]
# ### 1. 파일 생성하기

# %% [markdown]
# #### f = open("새파일.txt", 'w')
# #### f.close()

# %% [markdown]
# #### r - "읽기모드"   ,  w - "쓰기모드"      ,  a - "추가 모드"

# %% [markdown]
# ### 2. 파일을 쓰기 모드로 열어 출력값 적기

# %%
# writedata.py
f = open("doit/newfile.txt", 'w')
for i in range(1,11):
    data = "%d번째 줄입니다.\n" % i
    f.write(data)  # data를 파일 객체 f에 써라
f.close()

# %% [markdown]
# #### f.close()를 생략하더라도 프로그램 종료 시 파이썬 프로그램이 열려있는 파일의 객체를 자동으로 닫아 줌
# #### 쓰기 모드로 열었던 파일을 닫지 않고 다시 사용하려고 하면 오류 발생

# %% [markdown]
# ### 3. 프로그램의 외부에 저장된 파일을 읽는 여러 가지 방법

# %% [markdown]
# #### 파일의 첫 번째 줄을 읽어서 출력
# #### readline( )은 더 이상 읽을 줄이 없을 경우 None을 출력

# %%
# readline.py

f = open("doit/newfile.txt", 'r')   # 읽기 모드
line = f.readline()    # 첫 번째 줄을 읽어 출력
print(line)
f.close()
# Out:
# 1번째 줄입니다.

# %%
# readline.py

f = open("doit/newfile.txt", 'r')   # 읽기 모드
line = f.readline(5) # 숫자를 넣으면 인덱스 값 만큼 출력. 5를 넣으면 4인덱스까지 출력
print(line)
f.close()
# Out:
# 1번째 줄

# %%
# readline_all.py   모든 줄을 출력

f = open("doit/newfile.txt", 'r')   # 읽기 모드
while True:
    line = f.readline()    # 첫 번째 줄을 읽어 출력
    if not line: break     # readline()맨 끝엔 None이 출력되므로 break문 실행
    print(line) 
f.close()
# Out:
# 1번째 줄입니다.
#
# 2번째 줄입니다.
#
# 3번째 줄입니다.
#
# 4번째 줄입니다.
#
# 5번째 줄입니다.
#
# 6번째 줄입니다.
#
# 7번째 줄입니다.
#
# 8번째 줄입니다.
#
# 9번째 줄입니다.
#
# 10번째 줄입니다.
#
# 11 번째 줄입니다.
#
# 12 번째 줄입니다.
#
# 13 번째 줄입니다.
#
# 14 번째 줄입니다.
#
# 15 번째 줄입니다.
#
# 16 번째 줄입니다.
#
# 17 번째 줄입니다.
#
# 18 번째 줄입니다.
#
# 19 번째 줄입니다.

# %%
while 1:
    data = input()  # 1번 출력
    if not data: break
    print(data)     # 2번 출력
# Out:
# 1번째 줄입니다.
# 1번째 줄입니다.

# %%
# readlines.py

f = open("doit/newfile.txt", 'r')
lines = f.readlines()  # 파일의 모든 줄을 읽어들임
for line in lines:
    print(line)
    f.close()
print(type(line))
# Out:
# 1번째 줄입니다.
#
# 2번째 줄입니다.
#
# 3번째 줄입니다.
#
# 4번째 줄입니다.
#
# 5번째 줄입니다.
#
# 6번째 줄입니다.
#
# 7번째 줄입니다.
#
# 8번째 줄입니다.
#
# 9번째 줄입니다.
#
# 10번째 줄입니다.
#
# <class 'str'>

# %%
# readlines.py

f = open("doit/newfile.txt", 'r')
lines = f.readlines()  # 파일의 모든 줄을 읽어들임. 리스트 형식
print(lines)
# Out:
# ['1번째 줄입니다.\n', '2번째 줄입니다.\n', '3번째 줄입니다.\n', '4번째 줄입니다.\n', '5번째 줄입니다.\n', '6번째 줄입니다.\n', '7번째 줄입니다.\n', '8번째 줄입니다.\n', '9번째 줄입니다.\n', '10번째 줄입니다.\n', '11 번째 줄입니다.\n', '12 번째 줄입니다.\n', '13 번째 줄입니다.\n', '14 번째 줄입니다.\n', '15 번째 줄입니다.\n', '16 번째 줄입니다.\n', '17 번째 줄입니다.\n', '18 번째 줄입니다.\n', '19 번째 줄입니다.\n', '11 번째 줄입니다.\n', '12 번째 줄입니다.\n', '13 번째 줄입니다.\n', '14 번째 줄입니다.\n', '15 번째 줄입니다.\n', '16 번째 줄입니다.\n', '17 번째 줄입니다.\n', '18 번째 줄입니다.\n', '19 번째 줄입니다.\n']

# %%
# read.py

f = open("doit/newfile.txt", 'r')
data = f.read() # 파일의 내용 전체를 문자열로 반환
print(data)
f.close()
print(type(data))
# Out:
# 1번째 줄입니다.
# 2번째 줄입니다.
# 3번째 줄입니다.
# 4번째 줄입니다.
# 5번째 줄입니다.
# 6번째 줄입니다.
# 7번째 줄입니다.
# 8번째 줄입니다.
# 9번째 줄입니다.
# 10번째 줄입니다.
#
# <class 'str'>

# %% [markdown]
# ### 4. 파일에 새로운 내용 추가하기

# %%
# appdata.py

f = open("doit/newfile.txt", 'a')
for i in range(11, 20):
    data = "%d 번째 줄입니다.\n" % i
    f.write(data)
f.close()

# %% [markdown]
# ### 5. with문과 함께 사용하기
# - with문을 사용하면 구문이 종료될 때 파일을 자동으로 닫음
# - f.close()기능을 자동으로 수행

# %%
f = open("foo.txt", 'w')
f.write("Life is too short, you need python")
f.close()

# %%
# 같은 코드

with open("foo.txt", 'w') as f:
    f.write("Life is too short, you need python")

# %% [markdown]
# ### 6. sys모듈로 매개변수 추가
# - 명령 프롬프트 창에서 매개변수를 직접 입력하여 프로그램을 실행하는 방식(cmd: type a.txt)
# - 명령 프롬프트 명령어 [인수1, 인수2 ...]
# - sys모듈을 사용하여 매개변수 직접 입력 가능: import sys

# %%
# sys1.py

import sys

args = sys.argv[1:]
for i in args:
    print(i)
    
# python sys1.py aaa bbb ccc
# Out:
# -f
# C:\Users\geon0\AppData\Roaming\jupyter\runtime\kernel-06a299cc-0ac6-47a3-ae23-2db88582476b.json

# %% [markdown]
# ### p.180 연습문제 Q5

# %%
f1 = open("test.txt", 'w')
f1.write("Life is too short")
f1.close()  # 파일을 닫지 않은 상태에서 다시 열면 파일에 저장한 데이터를 불러들일 수 없음

f2 = open("test.txt", 'r')
print(f2.read())
f2.close()
# Out:
# Life is too short

# %%
# 위와 같은 코드

with open("test.txt", 'w')as f1:
    f1.write("Life is too short!")

with open("test.txt", 'r') as f2:
    print(f2.read())
# Out:
# Life is too short!

# %% [markdown]
# ### p.181 연습문제 Q6.

# %%
user_input = input("저장할 내용을 입력하세요: ")
f = open("test.txt",'a') # 작성 내용 유지한채로 새로 입력한 내용 추가위해 'a'사용
f.write(user_input)
f.write("\n") # 입력한 내용을 줄 단위로 구분하기 위해 줄 바꿈 문자 삽입
f.close()
# Out:
# 저장할 내용을 입력하세요: 하이

# %% [markdown]
# ### p.181 연습문제 Q7.

# %%
f = open('test2.txt', 'r')
body = f.read()   # test2.txt파일의 내용을 body에 저장
f.close()

body = body.replace('java', 'python')  # body 문자열에서 "java"를  "python"으로 변경

f = open('test2.txt', 'w') # 파일을 쓰기모드로 실행하여 저장
f.write(body)
f.close()

# %%
# 위와 같은 코드

with open('test2.txt', 'r') as f1:
    body = f1.read()

body = body.replace('java', 'python')

with open('test2.txt', 'w') as f2:
    f2.write(body)
